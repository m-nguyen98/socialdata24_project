# %% [markdown]
# # reviews.txt.gz conversion to .csv
#
# ### BeerAdvocate free-text reviews
# As the BeerAdvocate text reviews are formatted inconveniently for the use of Pandas library directly,
#
# the purpose of this ipynb notebook is to extract the .txt.gz file and convert it to a Pandas dateframe,
#
# which then later can be saved as in .csv format

# %%
import gzip
import pandas as pd

# %%
reviews_list=[]

with gzip.open('data/RateBeer/reviews.txt.gz', mode='rt', encoding='utf-8') as f:

   for line in f.readlines():
      line = line[line.find(': ')+len(': '):line.rfind('\n')]
      reviews_list.append(line)

# %%
n = 17 # number of attributes
list_of_lists = [reviews_list[i * n:(i + 1) * n] for i in range((len(reviews_list) + n - 1) // n )]

# %%
list_of_lists
# Out:
# [['33 Export (Gabon)',
#   '410549',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '5.0',
#   '1461664800',
#   'Manslow',
#   '175852',
#   '2',
#   '4',
#   '2',
#   '4',
#   '8',
#   '2.00',
#   'Puszka 0,33l dzięki Christoph . Kolor jasnozłoty, piana biała drobnoziarnista szybko opada. Aromat słodowy, lekko słodkie.Dość dobre. ',
#   ''],
#  ['Castel Beer (Gabon)',
#   '105273',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '5.2',
#   '1487329200',
#   'MAGICuenca91',
#   '442761',
#   '2',
#   '3',
#   '2',
#   '4',
#   '8',
#   '1.90',
#   'Cerveza pale lager gabonesa. MÃ¡s floja que la Regab.Aroma escaso, apariencia pÃ¡lida, muy poco cuerpo y poco regusto en el paladar.Si algÃºn dÃ\xada fuera a GabÃ³n pedirÃ\xada una mÃ¡s para volver a probarla y el resto del tiempo pedirÃ\xada la Regab sin duda, que tampoco es que sea nada del otro mundo, pero es superior a Ã©sta. ',
#   ''],
#  ['Castel Beer (Gabon)',
#   '105273',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '5.2',
#   '1466762400',
#   'Sibarh',
#   '288889',
#   '3',
#   '3',
#   '2',
#   '3',
#   '5',
#   '1.60',
#   'Kolor- złoty, klarowny. Piana - drobna, średnio wysoka, nie trwała. Zapach - lekki słodowy. Smak - lekki słÃ³d i chmiel, lekki kwasek, lekka słodycz i goryczka  ',
#   ''],
#  ['Castel Beer (Gabon)',
#   '105273',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '5.2',
#   '1451646000',
#   'fombe89',
#   '250510',
#   '4',
#   '3',
#   '1',
#   '2',
#   '5',
#   '1.50',
#   'Botella, de GabÃ³n regalo familiar.31/01/2015Color amarillo, aromas y sabores a maiz, cuerpo medio ',
#   ''],
#  ['Castel Beer (Gabon)',
#   '105273',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '5.2',
#   '1445594400',
#   'kevnic2008',
#   '122778',
#   '2',
#   '4',
#   '2',
#   '4',
#   '7',
#   '1.90',
#   'Many thanks for this beer to Erzengel. Pours light golden with medium head. Light bodied crisp taste with low carbonation. Sweet finish.  ',
#   ''],
#  ['Castel Beer (Gabon)',
#   '105273',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '5.2',
#   '1444644000',
#   'Beerhunter111',
#   '227834',
#   '2',
#   '3',
#   '2',
#   '3',
#   '9',
#   '1.90',
#   'Many thanks to Erzengel for sharing! Pours clear golden colour with a small white head. Aroma of grain, sweet malts and slight hops. Taste is grainy, bread, some hops, watery finish... ',
#   ''],
#  ['Castel Beer (Gabon)',
#   '105273',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '5.2',
#   '1444212000',
#   'Erzengel',
#   '83106',
#   '4',
#   '5',
#   '4',
#   '5',
#   '8',
#   '2.60',
#   'Many thanks to Travlr for this can!  Grainy nose. The beer starts smooth grainy. Not too deep but not bad. Easy to drink, hints of sweetness there, full grainy body, moderate to low bitterness in the end. Easy to drink!  ',
#   ''],
#  ['Castel Beer (Gabon)',
#   '105273',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '5.2',
#   '1430820000',
#   'Manslow',
#   '175852',
#   '2',
#   '4',
#   '2',
#   '3',
#   '6',
#   '1.70',
#   'Puszka pita w Gabonie. Kolor jasnosłomkowy, piana znika szybko. Aromat lekki słodowy. Smak słodkiego słodu. Nagazowanie słabe jak i samo piwo. ',
#   ''],
#  ['Castel Beer (Gabon)',
#   '105273',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '5.2',
#   '1401357600',
#   'Lowenbrau',
#   '37316',
#   '3',
#   '5',
#   '2',
#   '3',
#   '7',
#   '2.00',
#   '330ml bottle. 29-05-2014.From Gabon, courtesy of Fombe.In short: a sweet poor lager.Pours bright gold, clear, with nice white head. Short head retention, poor lacing. Skunky, adjunct aromas. Light body, average carbonation, crispy texture. Taste follows the nose, some sweet flavours. Very poor. ',
#   ''],
#  ['Castel Beer (Gabon)',
#   '105273',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '5.2',
#   '1374141600',
#   'seynie',
#   '75452',
#   '2',
#   '3',
#   '3',
#   '4',
#   '6',
#   '1.80',
#   'Light yellow with quickly disappearing foam top. Slightly more body than the other local beer, Regab. A little more malty but nothing very exciting about this beer ',
#   ''],
#  ['Castel Beer (Gabon)',
#   '105273',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '5.2',
#   '1245319200',
#   'Cletus',
#   '17111',
#   '4',
#   '4',
#   '2',
#   '4',
#   '8',
#   '2.20',
#   'Pours yellow with a large white head.  Smells of sweet creamed corn, some dry malt, tarte.  Tastes of stale hops and crisp with some grape like hints on the finish. ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1487329200',
#   'MAGICuenca91',
#   '442761',
#   '2',
#   '4',
#   '3',
#   '5',
#   '11',
#   '2.50',
#   'Una cerveza tipo lager al uso.Sin ser una buena cerveza, me sorprendiÃ³ que tuviese mÃ¡s nivel que algunas que aquÃ\xad (en EspaÃ±a) son veneradas. Ejemplo: Cruzcampo.He probado lagers mucho peores que Ã©sta, siendo de un paÃ\xads como GabÃ³n al que no se le presupone demasiada tradiciÃ³n cervecera.Aroma escaso, apariencia similar a la de todas las lager. Poco cuerpo y un sabor agradable al paladar pero sin mucho mÃ¡s.Cerveza que ronda el 4,5 - 5 sobre 10. ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1438855200',
#   'GenDV138',
#   '290599',
#   '3',
#   '5',
#   '3',
#   '5',
#   '10',
#   '2.60',
#   'Can at the DC Local Gathering on 8/1/2015, shared by Travlr. Clear golden yellow with off-white head. Aromas of corn, caramel. Tastes of corn, malt, caramel. Light body with a dry finish. ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1438509600',
#   'nimbleprop',
#   '38859',
#   '2',
#   '5',
#   '2',
#   '5',
#   '8',
#   '2.20',
#   '16oz can pours a clear gold with some cloudy, white head. Nose is OK, malt, corn, mild perfume. Flavor has corn and a little butter, yeast too. Watery finish. Could be worse. ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1438423200',
#   'Iphonephan',
#   '210140',
#   '2',
#   '3',
#   '3',
#   '3',
#   '9',
#   '2.00',
#   'From a 12 oz bottle at the RB Aug 1 tasting. Pours a clear gold with an off white head. feint head corn nose. flavors or grain and white bread. ok for the style. ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1438423200',
#   'solidfunk',
#   '128160',
#   '3',
#   '5',
#   '3',
#   '4',
#   '5',
#   '2.00',
#   'Actually not bad compared to many national lagers. Golden pour. Light straw and even a hint of barley. Can from Travlr.  ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1438423200',
#   'radagast83',
#   '26851',
#   '2',
#   '4',
#   '2',
#   '4',
#   '8',
#   '2.00',
#   '16oz can. Pours a very sad, pale yellow color, no head. fizzy carbonation immediately. Interesting. Light candy, not too sweet. some corn. boring. ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1438423200',
#   'Travlr',
#   '83882',
#   '2',
#   '2',
#   '2',
#   '4',
#   '3',
#   '1.30',
#   'Can muled from the source by Maki, thanks very much! Clear bright golden yellow color, scant head. Aroma of wet cardboard. Taste is bland watery lager, inoffensive enough.  ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1436263200',
#   'fombe89',
#   '250510',
#   '4',
#   '3',
#   '3',
#   '2',
#   '3',
#   '1.50',
#   'Botella, regalo familia. Color amarillo claro, aroma malta, carbonatacion alta ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1429437600',
#   'Manslow',
#   '175852',
#   '3',
#   '4',
#   '2',
#   '4',
#   '6',
#   '1.90',
#   'Butelka 0,66l alk 4,5% wypite w Gabonie w 2005r. Kolor jasnosłomkowy, piany brak, wodniste.Aromat cytrynowy, lekko kwaskowe, mocno gazowane.Smak niewyczuwalny, kwaskowe.Piwo afrykańskie typowe. ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1374141600',
#   'seynie',
#   '75452',
#   '3',
#   '2',
#   '2',
#   '4',
#   '5',
#   '1.60',
#   'Light local beer of Gabon. Carbonation disappears quickly, watery taste. Easy to drink though. ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1352718000',
#   'fonefan',
#   '38926',
#   '2',
#   '3',
#   '2',
#   '4',
#   '7',
#   '1.80',
#   'Bottle. [ As my country rating # 134 on ratebeer ].[ Courtesy of The Aarhus Crew ]. Clear light to medium orange yellow colour with a small, fizzy, fair lacing, fully diminishing, off-white to white head. Aroma is light moderate malty, grain, cereal, corn. Flavour is moderate sweet with a average duration, malty, cereal, dry, light salty, cardboard notes. Body is medium, texture is watery, carbonation is soft. [20120908] ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1347876000',
#   'Kingink',
#   '217452',
#   '4',
#   '5',
#   '3',
#   '6',
#   '7',
#   '2.50',
#   'As lagers go, very drinkable, especially in equatorial temperatures when served chilled. ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1346925600',
#   'Zita',
#   '98909',
#   '3',
#   '3',
#   '2',
#   '2',
#   '5',
#   '1.50',
#   'light sweet aroma,yellow,clear, white foam, lightly bitter, salty, light body, thin feel, flat, dry finish. ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1346925600',
#   'Hansen',
#   '5986',
#   '2',
#   '3',
#   '2',
#   '4',
#   '7',
#   '1.80',
#   'Yellow coloured and almost clear. Has a white head mostly diminishing. Fant aroma of...well..beer. Sweet flavor with a faint bitter finish. Creamy texture. ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1346925600',
#   'onystrom',
#   '26684',
#   '2',
#   '4',
#   '1',
#   '4',
#   '5',
#   '1.60',
#   'Clear yellow color with small head. Some bitterness but very weak and watery flavor. ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1346925600',
#   'Rasmus40',
#   '121469',
#   '2',
#   '3',
#   '2',
#   '3',
#   '6',
#   '1.60',
#   'Bottle @ chrisv10 tasting. Clear pale yellow with a small white head. Aroma is sweet, light malty and grainy. Flavor is medum sweet and light bitter. Dry and light bitter finish. Watery. 060912 ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1346925600',
#   'saxo',
#   '28282',
#   '2',
#   '3',
#   '2',
#   '4',
#   '6',
#   '1.70',
#   'Bottle. Small head with short duration. Color is golden. Aroma and taste are malt, water and hops.  ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1346925600',
#   'HenrikSoegaard',
#   '17613',
#   '1',
#   '2',
#   '2',
#   '3',
#   '6',
#   '1.40',
#   'Bottle. Frothy white fair mostly deminishing head. Pale yellow colour. Light malty and hoppy aroma. Short light bitter flavor. Light bitter short finish. Watery palate. ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1346925600',
#   'chrisv10',
#   '91218',
#   '2',
#   '3',
#   '2',
#   '3',
#   '7',
#   '1.70',
#   'Bottle from Ethnic store very close to the Porte de Vances metro station, Paris. Clear pale golden with small white head. Aroma is malt and grainy. Flavour is malt, grainy, hop, butter and a little watery. ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1245319200',
#   'Cletus',
#   '17111',
#   '3',
#   '2',
#   '1',
#   '2',
#   '4',
#   '1.20',
#   'Pours gold with a thin white head.  Smells of apples and cardboard.  Tastes of stale hops, some skunky hints and buttery. ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1215511200',
#   'lgklotet',
#   '30812',
#   '2',
#   '1',
#   '2',
#   '1',
#   '5',
#   '1.10',
#   'Bottle, thx Omhper. All my notes say for this beer is DMS. Still, not alltogether nasty. ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1204196400',
#   'rickgordon',
#   '6517',
#   '2',
#   '2',
#   '2',
#   '2',
#   '6',
#   '1.40',
#   ' Bottled. Thx omhper! Pale golden colour with low white head. Pale malty nose with hints of cooked vegetables. Fizzy mouthfeel with pale malty backbone and stale hops, yet no major off flavours. No bitterness detected here. ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1204023600',
#   'oh6gdx',
#   '19328',
#   '2',
#   '3',
#   '2',
#   '3',
#   '5',
#   '1.50',
#   'Bottled (thanks omhper!). Yellowish golden colour with minor white head. Aroma is maize, some rubber and mild notes of hay and rubber. Flavour is very similar to this, but the maize is the strongest. Some mild hoppyness in the finish.  ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1203850800',
#   'ante',
#   '6974',
#   '2',
#   '3',
#   '1',
#   '2',
#   '5',
#   '1.30',
#   'Bottled, courtesy of omhper. Pale golden with a low firm white head. Corn, grass, metal and straw in the light aroma. Thin fizzy flavour metal and wet hay. Very short finish, hints of metal and sulphur.  ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1209117600',
#   'omhper',
#   '2778',
#   '1',
#   '2',
#   '2',
#   '2',
#   '6',
#   '1.30',
#   'Bottled.  Pale golden, very brief head. Vegetable aroma. Medium sweet with fizzy mouthfeel. Some stale hops and boiled vegetables. Feels industrial and dull.  ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1202468400',
#   'jclaude',
#   '69327',
#   '3',
#   '10',
#   '5',
#   '10',
#   '20',
#   '4.80',
#   'I nreally think that people that put comments on this page should know what they are talking about. This is just one of the finest brew in the african market. So please stop misleading people. So Vive la regab.... As they say over there....... ',
#   ''],
#  ['Régab',
#   '19445',
#   'Sobraga',
#   '3198',
#   'Pale Lager',
#   '4.5',
#   '1088157600',
#   'Nuffield',
#   '3806',
#   '2',
#   '2',
#   '2',
#   '2',
#   '3',
#   '1.10',
#   'Yellow body with a densely formed head, dissipating moderately fast.  Grassy dry with a very curious metallic edge in the finish (qualitatively different than the metallic bitterness Iâ\x80\x99ve had in American lagers).  Something in the flavor reminded me of a chili.  Not good at all.  Thanks to John W. for bringing back a large bottle from his travels in Africa. ',
#   ''],
#  ['Ards Bally Black Stout',
#   '155699',
#   'Ards Brewing Co.',
#   '13538',
#   'Stout',
#   '4.6',
#   '1429178400',
#   'ciaranc',
#   '151109',
#   '3',
#   '7',
#   '2',
#   '8',
#   '17',
#   '3.70',
#   'Bottle, gift from Aaron. Black, big head, lots of fizz. Head doesnâ\x80\x99t stick around. Roast, bitter coffee notes, roasted barley, light body, loads of carbonation. Decent flavour and very drinkable ',
#   ''],
#  ['Ards Bally Black Stout',
#   '155699',
#   'Ards Brewing Co.',
#   '13538',
#   'Stout',
#   '4.6',
#   '1427796000',
#   'Rowlymo',
#   '198957',
#   '4',
#   '7',
#   '4',
#   '8',
#   '15',
#   '3.80',
#   '500ml Bottle in Bittles bar Belfast. Chocolate rich full of flavours especially after a Guinness  ',
#   ''],
#  ['Ards Bally Black Stout',
#   '155699',
#   'Ards Brewing Co.',
#   '13538',
#   'Stout',
#   '4.6',
#   '1421665200',
#   'Don2711',
#   '285162',
#   '4',
#   '8',
#   '5',
#   '7',
#   '17',
#   '4.10',
#   'Great one and made very local to me. Bottle bought as a treat. Lovely aroma with caramel and chocolate. Appearance dark with cream head. Taste was caramel and chocolate. A little sweet but no harm. Lovely on palate. Will try again. Would love to try a cask.  ',
#   ''],
#  ['Ards Bally Black Stout',
#   '155699',
#   'Ards Brewing Co.',
#   '13538',
#   'Stout',
#   '4.6',
#   '1380621600',
#   'genegenie',
#   '224156',
#   '5',
#   '8',
#   '3',
#   '5',
#   '19',
#   '4.00',
#   'Deep roasted aroma, good dark brown/black colour and delicious palate of dark coffee stout. Great stuff.  ',
#   ''],
#  ['Ards Bally Black Stout',
#   '155699',
#   'Ards Brewing Co.',
#   '13538',
#   'Stout',
#   '4.6',
#   '1371549600',
#   'kiwianer',
#   '88501',
#   '4',
#   '7',
#   '4',
#   '7',
#   '14',
#   '3.60',
#   'The head is medium, the body black. It smells roasty, coffee, chocolate. The taste is roasty, coffee, chocolate, a bit sweet, balanced, nice. 12/11/12/12/12/12 ',
#   ''],
#  ['Ards Bally Black Stout',
#   '155699',
#   'Ards Brewing Co.',
#   '13538',
#   'Stout',
#   '4.6',
#   '1321527600',
#   'Beersiveknown',
#   '128086',
#   '5',
#   '7',
#   '5',
#   '7',
#   '16',
#   '4.00',
#   'Cask@ Belfast beer fest. Dark brown black with lively white head. Subtle roast barley nose with sweet milk chocolate, slight chalk and roast finish. ',
#   ''],
#  ['Ards Belfast 366',
#   '239097',
#   'Ards Brewing Co.',
#   '13538',
#   'Golden Ale/Blond Ale',
#   '4.2',
#   '1385204400',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '6',
#   '3',
#   '5',
#   '12',
#   '3.00',
#   '[email\xa0protected]/*  */Hazy golden blonde with grainy aroma and notes if citrus. Flavour a bit muddy...hopsand grain clash a bit but plenty of citrus too ',
#   ''],
#  ['Ards Bittles Christmas',
#   '380930',
#   'Ards Brewing Co.',
#   '13538',
#   'Bitter',
#   '4.2',
#   '1449658800',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '6',
#   '4',
#   '7',
#   '13',
#   '3.40',
#   'Bottle, bottlesclear pale amber brown, big fluffy beige head. Clean malty mineral dry nose, moderate body, decently bitter, touch of marmalade but largely biscuit malt. Decent best bitter but not obviously xmassy. ',
#   ''],
#  ['Ards Bittles Citra Autumn Ale',
#   '234108',
#   'Ards Brewing Co.',
#   '13538',
#   'American Pale Ale',
#   '5.1',
#   '1382263200',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '7',
#   '3',
#   '6',
#   '14',
#   '3.40',
#   'Bottle at Bittles, BelfastHazy pale blonde with lightly tropical nose. Medium bodied, shortcake malt, mangoes. Dulled by the fact it was served far too cold! ',
#   ''],
#  ['Ards Cardy Man',
#   '396830',
#   'Ards Brewing Co.',
#   '13538',
#   'Stout',
#   '4.2',
#   '1455879600',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '6',
#   '3',
#   '6',
#   '12',
#   '3.10',
#   'Bottle at bittlesopaque dark chestnut with beige lacing. Quite dry with lively carbonation, a lot of roast and cocoa. Initially little in way of cardamom but a spicy tingle creeps in at end but only because Iâ\x80\x99m searching for it. A little too cold really, becomes dusty, sweeter, thinner as it warms. ',
#   ''],
#  ['Ards Hip Hop',
#   '256772',
#   'Ards Brewing Co.',
#   '13538',
#   'American Pale Ale',
#   '5.2',
#   '1409911200',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '7',
#   '4',
#   '7',
#   '15',
#   '3.70',
#   'Bottle at bittlesHazy burnished gold with fluffy white lacing. Soft floral melon and kiwi nose. Medium body and carbonation fruity peach and apricot. Light bitterness, creamy texture, wheat spiciness. Dry fruity finish. ',
#   ''],
#  ['Ards Pig Island Pale Ale',
#   '160664',
#   'Ards Brewing Co.',
#   '13538',
#   'Bitter',
#   '5.2',
#   '1382436000',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '7',
#   '4',
#   '5',
#   '13',
#   '3.30',
#   'Bottle at Bittles Bar, BelfastHazy amber brown with herbal hop nose. Some initial light fruit flavours and resinous bitterness with balancing digestive biscuit malts. Fairly full bodied, one to try cask conditioned. ',
#   ''],
#  ['Ards Pig Island Pale Ale',
#   '160664',
#   'Ards Brewing Co.',
#   '13538',
#   'Bitter',
#   '5.2',
#   '1371549600',
#   'kiwianer',
#   '88501',
#   '4',
#   '7',
#   '3',
#   '5',
#   '14',
#   '3.30',
#   'The head is stable, the body golden, orange. It smells bitter, hoppy, a bit fruity. The taste is a little bit strange, bitter, hoppy, bit fruity. Overall ok. 12/12/9/8/13/10 ',
#   ''],
#  ['Ards Pig Island Pale Ale',
#   '160664',
#   'Ards Brewing Co.',
#   '13538',
#   'Bitter',
#   '5.2',
#   '1385550000',
#   'genegenie',
#   '224156',
#   '5',
#   '8',
#   '4',
#   '9',
#   '18',
#   '4.40',
#   'Hard to find but worth it when you do. A refreshing pale ale with the most fantastic subtle tones of orange. One of my favourites! ',
#   ''],
#  ['Ards Pig Island Pale Ale',
#   '160664',
#   'Ards Brewing Co.',
#   '13538',
#   'Bitter',
#   '5.2',
#   '1339581600',
#   'visionthing',
#   '91324',
#   '4',
#   '7',
#   '4',
#   '7',
#   '14',
#   '3.60',
#   '50cl bottle (4,8% ABV) at Bittles Bar, Belfast. Pours slightly hazy dark golden with an off-white head. Hoppy aroma with tropical fruits, malt and hints of caramel and spices. Fruity and sweet with a well balanced bitterness. Well crafted. Medium body. Quite refreshing and a nice pale ale, actually I thinks itâ\x80\x99s one of the best English Pale Ales I have tasted. A nice surprise! ',
#   ''],
#  ['Ards Rockin\x92 Goose',
#   '177517',
#   'Ards Brewing Co.',
#   '13538',
#   'Irish Ale',
#   '4.4',
#   '1385377200',
#   'stjamesgate',
#   '159866',
#   '3',
#   '7',
#   '3',
#   '7',
#   '15',
#   '3.50',
#   'On gravity at the Belfast Beer Festival, 2013.Fairly light oxblood with no head. Bits of chocolate, roast and black grape on the nose. Grape soda, a spec of chocolate, some prune, coffee hard candy, and a bit of spice. Spiced apple tart finish and dry linger. Thin, clean, slight.No real complexity, too thin, no roast and far too sweet. A stretch to call it a mild, as the catalog said. Not worth the 4.4%; disappointing for a local. ',
#   ''],
#  ['Ards Rockin\x92 Goose',
#   '177517',
#   'Ards Brewing Co.',
#   '13538',
#   'Irish Ale',
#   '4.4',
#   '1342951200',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '7',
#   '4',
#   '6',
#   '13',
#   '3.40',
#   'Bottle at bittles bar Belfast.Pours hazy amber tinged Brown with caramel and earthy malt nose. Has some chocolate, red berries and caramel notes. Well carbonated. ',
#   ''],
#  ['Ards Rockin\x92 Goose',
#   '177517',
#   'Ards Brewing Co.',
#   '13538',
#   'Irish Ale',
#   '4.4',
#   '1340532000',
#   'visionthing',
#   '91324',
#   '3',
#   '6',
#   '3',
#   '6',
#   '12',
#   '3.00',
#   '50cl bottle at Bittles Bar, Belfast. Pours slightly hazy amber with an off-white hed. Lightly fruity and hoppy aroma with caramel and malt. Sweet, lightly fruity and malty with a well balancd bitterness. Well crafted ale, but slightly boring. Nice bitterness in the finish. Easy to drink. (2011-06-09) ',
#   ''],
#  ['Ards Scrabo Gold',
#   '299091',
#   'Ards Brewing Co.',
#   '13538',
#   'Golden Ale/Blond Ale',
#   '4.9',
#   '1416135600',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '6',
#   '4',
#   '7',
#   '12',
#   '3.30',
#   'Cask at Belfast Beer Festival 2014Mid gold, biscuit malt aroma. Medium bodied, bready wheat with spicey notes, touch of bitterness but easy drinking malt led pleasant ale. ',
#   ''],
#  ['Ards Single Hop Nelson Sauvin Pale Ale',
#   '253129',
#   'Ards Brewing Co.',
#   '13538',
#   'American Pale Ale',
#   '5.8',
#   '1397210400',
#   'Rob_D_UK',
#   '257161',
#   '3',
#   '7',
#   '3',
#   '6',
#   '12',
#   '3.10',
#   'I had this on tap while visiting Belfast. Poured was quite light. As indicated in the description there was a lot of similarity with white wine. ',
#   ''],
#  ['Ards Summer Ale',
#   '365410',
#   'Ards Brewing Co.',
#   '13538',
#   'Wheat Ale',
#   '5.0',
#   '1444039200',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '6',
#   '4',
#   '7',
#   '13',
#   '3.40',
#   'Bottle at bittlesfull bodied hazy pale golden amber with fluffy offwhite head. clean slightly floral aroma, light bitterness, a hint of citrus and bready wheat as it warms. A few more hops could have really made this one shine ',
#   ''],
#  ['Bittles Aged Winter Ale',
#   '313889',
#   'Ards Brewing Co.',
#   '13538',
#   'English Strong Ale',
#   '6.0',
#   '1424602800',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '6',
#   '4',
#   '7',
#   '14',
#   '3.50',
#   'bottle at home from Bittles barhazy earwax amber with lazy fob on head, pale beige white colour. Wheaty shredded wheat nose, deep earthy spices, nutmeg, cake batter, slight wet cardboard and plenty of fruity yeast esters. Rich toasty cocoa malt, earthy dryness, plum jam on toast fairly spiky carbonation. some porter-like tendencies ',
#   ''],
#  ['Bittles East Coast',
#   '336216',
#   'Ards Brewing Co.',
#   '13538',
#   'American Pale Ale',
#   '5.0',
#   '1432634400',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '6',
#   '4',
#   '5',
#   '11',
#   '3.00',
#   'Bottle at bittleshazy pale amber-blonde with fluffy off-white head. herbal aroma, dry, lightly bitter, flinty, a little bland ',
#   ''],
#  ['Barrahooley Black IPA',
#   '318125',
#   'Barrahooley Craft Brewery',
#   '22304',
#   'Black IPA',
#   '4.85',
#   '1438682400',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '7',
#   '4',
#   '7',
#   '14',
#   '3.60',
#   'Bottle at ABVFesthazy dark cola brown with fluffy tan head. pine, lght citrus and toast on nose. moderate body, light carbonation, dry coca, not overly bitter, some citrus notes. ',
#   ''],
#  ['Barrahooley Dry Stout',
#   '398981',
#   'Barrahooley Craft Brewery',
#   '22304',
#   'Stout',
#   '4.5',
#   '1456657200',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '7',
#   '4',
#   '7',
#   '14',
#   '3.60',
#   'bottle at home from the vineyard, belfastfull bodied, dry and earthy, toasty and roast, classic dry stout. Easy drinking, medium body and carbonation. ',
#   ''],
#  ['Barrahooley Pale Ale',
#   '318126',
#   'Barrahooley Craft Brewery',
#   '22304',
#   'American Pale Ale',
#   '4.85',
#   '1456657200',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '6',
#   '4',
#   '6',
#   '12',
#   '3.20',
#   'Bottle at home from the vineyardplenty of cascade here, citrus, herbal bitterness, slight unpleasant yeast note popping in at back on moderate body, dab of biscuit malt, decent pale ',
#   ''],
#  ['Boundary / Brick / Ulster Exiles / Bullfinch Screwball',
#   '532818',
#   'Boundary',
#   '22818',
#   'India Pale Ale (IPA)',
#   '6.1',
#   '1500112800',
#   'Stuu666',
#   '178977',
#   '3',
#   '7',
#   '4',
#   '8',
#   '15',
#   '3.70',
#   'Bottle at home. Pours deep orange, nose is raspberry, funk, vanilla, taste is juicy, tart raspberry, creamy, sweet  ',
#   ''],
#  ['Boundary / Galway Bay Border Hopper (bretted)',
#   '407134',
#   'Boundary',
#   '22818',
#   'India Pale Ale (IPA)',
#   '8.8',
#   '1459245600',
#   'allmyvinyl',
#   '128401',
#   '3',
#   '8',
#   '4',
#   '8',
#   '15',
#   '3.80',
#   'Keg at the Bow. Pours hazy orange with a thin white head. Aromas of funk, citrus, coconut. Taste is more of the same. Dry finish. Interesting.  ',
#   ''],
#  ['Boundary / Galway Bay Border Hopper (bretted)',
#   '407134',
#   'Boundary',
#   '22818',
#   'India Pale Ale (IPA)',
#   '8.8',
#   '1459245600',
#   'Stuu666',
#   '178977',
#   '4',
#   '8',
#   '4',
#   '8',
#   '16',
#   '4.00',
#   'Keg at the bow bar. Pours deep orange, nose is funky, citrus, pine, light coconut, taste is similar, dry, juicy.  ',
#   ''],
#  ['Boundary / Galway Bay Border Hopper (clean)',
#   '336169',
#   'Boundary',
#   '22818',
#   'American Strong Ale ',
#   '7.2',
#   '1432634400',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '8',
#   '3',
#   '7',
#   '14',
#   '3.60',
#   '[email\xa0protected]/*  */dirty hazy murky ruby with big pine pithy nose, sticky, sweet rich, heavy, pine very much an american style barley wine rather than IIPA but this is the "clean" (i.e. Brett free) version. look forward to trying the aged version in the future. ',
#   ''],
#  ['Boundary / Heaney Farmhouse No Coast',
#   '526627',
#   'Boundary',
#   '22818',
#   'Imperial IPA',
#   '9.8',
#   '1498557600',
#   'Stuu666',
#   '178977',
#   '3',
#   '8',
#   '3',
#   '8',
#   '15',
#   '3.70',
#   'Keg at ushers. Pours golden amber, nose is grapefruit, pineapple, mango, taste is similar, juicy, sweet.  ',
#   ''],
#  ['Boundary / Mad Hatter Milk Agitator',
#   '437440',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '4.1',
#   '1484650800',
#   'Padchenko',
#   '272492',
#   '4',
#   '8',
#   '4',
#   '6',
#   '13',
#   '3.50',
#   'Lovely fruity aroma. Mostly sour with a small amount of sweetness. Blueberry and hazelnut are prominent. Pours dark red with no head. ',
#   ''],
#  ['Boundary / Mad Hatter Milk Agitator',
#   '437440',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '4.1',
#   '1476957600',
#   'Theydon_Bois',
#   '208877',
#   '4',
#   '6',
#   '4',
#   '6',
#   '14',
#   '3.40',
#   'Bottle split at Chris & Ruthâ\x80\x99s pre GBBF Shindig, 07/08/16.Murky red with a well appointed crimson cap.Nose is tangy berries, raspberry jam, damp straw.Taste comprises tarte blueberries, straw, citric rinds, grains, mineral notes, pink berry fizz.Medium bodied, fine carbonation, semi drying close.Decent enough â\x80\x99Linner. ',
#   ''],
#  ['Boundary / Mad Hatter Milk Agitator',
#   '437440',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '4.1',
#   '1476093600',
#   'mR_fr0g',
#   '108099',
#   '4',
#   '4',
#   '3',
#   '6',
#   '13',
#   '3.00',
#   'Bottle shared at the pre GBBF chrisoâ\x80\x99s tasting day 2 07/08/2016. A nice pink purple coloured pour with a a fine pink head. Aroma is sour milk, stale grains, purple fruits, plum funky sour, stale. Flavour is composed of purple plum tart fruits, raspeberry, milky. Palate is grainy, pithy, highish carbonation tannin. Meh.  ',
#   ''],
#  ['Boundary / Mad Hatter Milk Agitator',
#   '437440',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '4.1',
#   '1476007200',
#   'minutemat',
#   '265702',
#   '4',
#   '7',
#   '3',
#   '7',
#   '15',
#   '3.60',
#   '330ml bottle @ Indy-Man, courtesy of the brewer! Many thanks. Pours hazy reddish brown, small off-white head. Aroma is earthy nutty. Taste is milky, earthy hazlenut with very faint berries. Different. ',
#   ''],
#  ['Boundary / Mad Hatter Milk Agitator',
#   '437440',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '4.1',
#   '1475402400',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '7',
#   '4',
#   '7',
#   '14',
#   '3.60',
#   'bottle shared with chris-o gathering and draught at ABV Nutty, tart aroma. Medium bodied, juicy blueberry fruit, lactose, lactic, bright  ',
#   ''],
#  ['Boundary / Mad Hatter Milk Agitator',
#   '437440',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '4.1',
#   '1473847200',
#   'The_Osprey',
#   '249130',
#   '4',
#   '7',
#   '4',
#   '7',
#   '15',
#   '3.70',
#   'August 2016 - Bottle share at Chrisoâ\x80\x99s Sunday Shindig. Thanks! As â\x80\x99Boundary Milk Agitatorâ\x80\x99. Reddy purple, opaque, pinky foamy head. Aroma is mixed berries - blueberry and raspberry in particular. Body is smooth with soft carbonation. Taste is redcurrant, raspberry, some earthy vibes towards the finish. Pretty nice. (3.7) ',
#   ''],
#  ['Boundary / Mad Hatter Milk Agitator',
#   '437440',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '4.1',
#   '1471773600',
#   'rlgk',
#   '7982',
#   '3',
#   '7',
#   '3',
#   '7',
#   '14',
#   '3.40',
#   'Chris and Ruthâ\x80\x99s Shindig 2016, Sunday. Hazy reddish beer with a small head. Fruity raspberry aroma, nuts, grapes, caramel notes. Tart raspberry flavor, grapes, hazelnuts, some floral notes. Ok beer ',
#   ''],
#  ['Boundary / Mad Hatter Milk Agitator',
#   '437440',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '4.1',
#   '1470996000',
#   'Benzai',
#   '130058',
#   '3',
#   '7',
#   '3',
#   '8',
#   '15',
#   '3.60',
#   'Sampled @ ChrisO Pre-GBBF Shindig. Opaque murky red color, averagecsized off-white head. Smell and taste are moderately red fruit, nice mix between red fruit and bitter. Decent beer. ',
#   ''],
#  ['Boundary / Mad Hatter Milk Agitator',
#   '437440',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '4.1',
#   '1470823200',
#   'planky84',
#   '85632',
#   '3',
#   '7',
#   '4',
#   '7',
#   '14',
#   '3.50',
#   'Bottle at Chris and Ruthâ\x80\x99s pre-GBBF Shindig, 2016 (Sunday sesh.) Hazy red coloured pour, light pink head. Red fruit and berry aroma. Same action in the flavour. Very smooth.  ',
#   ''],
#  ['Boundary / Mad Hatter Milk Agitator',
#   '437440',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '4.1',
#   '1470564000',
#   'Beerhunter111',
#   '227834',
#   '4',
#   '6',
#   '4',
#   '6',
#   '14',
#   '3.40',
#   'Pre-gbbf-shinding. TrÃ¼bes rÃ¶tlich pinkes Bier mit einer ordentlichen pinken schaumkrone. Geruch nach roten Beeren, Kirschen, Joghurt. Geschmack trocken fruchtig, holzig, milchig.  ',
#   ''],
#  ['Boundary / Neill & Ross Adega',
#   '447427',
#   'Boundary',
#   '22818',
#   'Sour/Wild Ale',
#   '7.0',
#   '1487761200',
#   'anders37',
#   '18419',
#   '3',
#   '7',
#   '3',
#   '7',
#   '16',
#   '3.60',
#   'Bottle. Pours a slightly hazy golden color with a small white head. Has a fruity malty weak sour funky raspberry aroma. Fruity malty weak sour funky raspberry flavor. Has a fruity weak sour raspberry finish.  ',
#   ''],
#  ['Boundary / Neill & Ross Adega',
#   '447427',
#   'Boundary',
#   '22818',
#   'Sour/Wild Ale',
#   '7.0',
#   '1486378800',
#   'fonefan',
#   '38926',
#   '3',
#   '7',
#   '3',
#   '8',
#   '15',
#   '3.60',
#   'Bottle 750ml. corked. [ As Boundary / Neill & Ross Adega ].Unclear medium yellow orange color with a average, frothy, good lacing, mostly lasting, off-white head. Aroma is moderate malty, pale malt, wood, barnyard, sweet malt, apple - wine. Flavor is moderate sweet and light acidic with a long duration, sweet malt, apple - wine, funky, farmyard, tart, raspberry notes. Body is medium, texture is oily to watery, carbonation is soft. [20161229] 7-3-8-3-15  ',
#   ''],
#  ['Boundary / Neill & Ross Adega',
#   '447427',
#   'Boundary',
#   '22818',
#   'Sour/Wild Ale',
#   '7.0',
#   '1483009200',
#   'madsberg',
#   '5011',
#   '4',
#   '7',
#   '4',
#   '7',
#   '14',
#   '3.60',
#   'Bottled. Amber coloured. Unclear. No head. Aroma. Light raspberries. Sourness, earth. Flavour. Raspberries, sourness, earth. Medium bodied. Ends sourish and acidic.  ',
#   ''],
#  ['Boundary / Neill & Ross Adega',
#   '447427',
#   'Boundary',
#   '22818',
#   'Sour/Wild Ale',
#   '7.0',
#   '1483009200',
#   'Borup',
#   '41169',
#   '4',
#   '7',
#   '4',
#   '8',
#   '16',
#   '3.90',
#   '75 cl. bottle. Hazy golden colour with a white head. Aroma and flavour of tartness, fruit, yeast, sourness and raspberries. ',
#   ''],
#  ['Boundary / Neill & Ross Adega',
#   '447427',
#   'Boundary',
#   '22818',
#   'Sour/Wild Ale',
#   '7.0',
#   '1483009200',
#   'yespr',
#   '30149',
#   '4',
#   '8',
#   '4',
#   '8',
#   '16',
#   '4.00',
#   '75 cl bottle. Pours cloudy yellow to orange with a small white head. Aroma is fruity. Peachy and slight citrusy. Peachy and mellow fruity. Crisp hoppy. Smooth fruity finish. Raspberry fruity finish. ',
#   ''],
#  ['Boundary / Outland / Kinnegar / White Hag Pink Sunglasses',
#   '526629',
#   'Boundary',
#   '22818',
#   'Zwickel/Keller/Landbier',
#   '4.5',
#   '1499162400',
#   'cgarvieuk',
#   '36509',
#   '3',
#   '6',
#   '3',
#   '6',
#   '12',
#   '3.00',
#   '3Keg at the ushers ...Golden yellow.. Thin white lacing.. Soft herbal grassy orange... Dry bitter orange.. Little lemonade like  ',
#   ''],
#  ['Boundary / Outland / Kinnegar / White Hag Pink Sunglasses',
#   '526629',
#   'Boundary',
#   '22818',
#   'Zwickel/Keller/Landbier',
#   '4.5',
#   '1498557600',
#   'Stuu666',
#   '178977',
#   '3',
#   '6',
#   '3',
#   '6',
#   '13',
#   '3.10',
#   'Keg at ushers. Pours golden orange, nose is biscuity toffee, light fruit, taste is lemon, toffee, odd finish  ',
#   ''],
#  ['Boundary / Outland Pari Gagnant',
#   '526630',
#   'Boundary',
#   '22818',
#   'Saison',
#   '6.0',
#   '1500026400',
#   'cgarvieuk',
#   '36509',
#   '3',
#   '7',
#   '2',
#   '7',
#   '14',
#   '3.30',
#   'Keg at ushers... Hazy amber... Thin white lacing... Soft dru salty lemon fruits nose... Long dry salty fruits 3.3 bottle at home .. murky amber .. thin white lacing .. soft zezty peach lemon fruit nose ... juicy zezty fruit ... long floral fruit 3.5 ',
#   ''],
#  ['Boundary / Outland Pari Gagnant',
#   '526630',
#   'Boundary',
#   '22818',
#   'Saison',
#   '6.0',
#   '1498557600',
#   'Stuu666',
#   '178977',
#   '4',
#   '7',
#   '3',
#   '6',
#   '13',
#   '3.30',
#   'Keg at ushers. Pours hazy orange, nose is banana, citrus, light spice, taste is sweet, fruity, dry. ',
#   ''],
#  ['Boundary / Rascals Grand So ',
#   '447432',
#   'Boundary',
#   '22818',
#   'Session IPA',
#   '4.2',
#   '1475402400',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '8',
#   '4',
#   '8',
#   '16',
#   '4.00',
#   'keg at boundary taproomits not supposed to have brett character but this has poured through a tap that previously had border hopper but it actually works rather well. Dry, pithy, bitter saison, fruity, slight farmyard aroma, bretty well balanced. ',
#   ''],
#  ['Boundary /Galway Bay A Berliner Vice #1',
#   '336168',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '2.7',
#   '1446721200',
#   'jamestulloch',
#   '138957',
#   '4',
#   '6',
#   '3',
#   '7',
#   '12',
#   '3.20',
#   'Bottle from The Beerhive. Hazy pale golden body with a thin white head. Faint lacing. Aroma of paper, lemon, minerals and orange pith. Flavour of weak lemon, watery malt and salted cracker. Thin body with a watery texture. Light fizz. Not much zing to this, but itâ\x80\x99s ok. ',
#   ''],
#  ['Boundary /Galway Bay A Berliner Vice #1',
#   '336168',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '2.7',
#   '1432634400',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '7',
#   '4',
#   '7',
#   '14',
#   '3.60',
#   '[email\xa0protected]/*  */hazy pale blonde/white, super lactic, super tart, lemony, slightly fruity, sharp, acidic, moderate body, light in muth ',
#   ''],
#  ['Boundary A Berliner Vice #2',
#   '386909',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '1.9',
#   '1477476000',
#   'Lonick',
#   '152888',
#   '3',
#   '8',
#   '3',
#   '7',
#   '16',
#   '3.70',
#   'Bottle @cgarvieuk - The Xmas Tasting 2016. Pours golden with a white head. Nose is funk, lemon, slight cheese. Taste is fruity, lemon and lime, funk and a really nice white wine vibe going on. ',
#   ''],
#  ['Boundary A Berliner Vice #2',
#   '386909',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '1.9',
#   '1470736800',
#   'Stuu666',
#   '178977',
#   '3',
#   '7',
#   '4',
#   '8',
#   '15',
#   '3.70',
#   'Bottle at the xmas tasting. Pours clear pale golden, nose is funky, fruity, sherbert, taste is quite sour, lemon, chalky, sharp. ',
#   ''],
#  ['Boundary A Berliner Vice #2',
#   '386909',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '1.9',
#   '1469354400',
#   'McNeillR',
#   '150807',
#   '3',
#   '8',
#   '4',
#   '8',
#   '17',
#   '4.00',
#   'Very murky very pale with an initially vibrant bubbly pillow of head dissipating to a soft white ring. Nose is earthy and bright vinious with a classic kettle sour scratch. Initial taste is pure quench juice, like a keen radler - barrel evident enough. Carbonation is very firm, chalky and gummy mouthfeel. Finishes chalky melon and a decent citrusy grape buzz on the linger. How this is 1.9% Iâ\x80\x99ve no idea, incredibly flavourful without being super-smash juice.Bottle, Second Annual Xmas Tasting, Vineyard Belfast  ',
#   ''],
#  ['Boundary A Berliner Vice #2',
#   '386909',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '1.9',
#   '1469354400',
#   'allmyvinyl',
#   '128401',
#   '4',
#   '7',
#   '4',
#   '6',
#   '14',
#   '3.50',
#   'Bottle at the 2nd Annual Garvie Christmas Tasting. Pours clear straw yellow with a thin white head. Aromas of funky starburst. Light lactic note. Taste is sharp lemon sour. Good mouthfeel. Sour finish.  ',
#   ''],
#  ['Boundary A Berliner Vice #2',
#   '386909',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '1.9',
#   '1469354400',
#   'cgarvieuk',
#   '36509',
#   '3',
#   '7',
#   '3',
#   '6',
#   '13',
#   '3.20',
#   'bottle at home ... golden yellow .. big white head .. soft herbal fruit nose ... dry zezty floral .. tasrt lemon ... soft tart fruit ... dry tart fruits ... soft zezt lemonligth lacitic finish.. ligth funk ',
#   ''],
#  ['Boundary A Berliner Vice #2',
#   '386909',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '1.9',
#   '1468231200',
#   'DSG',
#   '47143',
#   '3',
#   '8',
#   '3',
#   '7',
#   '15',
#   '3.60',
#   'Bottle sample at a tasting at Tomâ\x80\x99s place. Thanks Tom L. Cloudy pale yellow. Great lactic aroma, fruity. Tart flavor, dry, lactic, with some smoky wood, fruitiness. Quite light-bodied. Very nice and refreshing. ',
#   ''],
#  ['Boundary a Berliner Vice #3',
#   '364610',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '2.7',
#   '1452164400',
#   'McNeillR',
#   '150807',
#   '2',
#   '6',
#   '4',
#   '8',
#   '16',
#   '3.60',
#   'Very hazy, milky golden and light ringed white head. Nose is eggy, big sour. Initial taste is lean pineapple, fusty melon. Vibrant carbonation and lean enough mouthfeel. Finishes clean berry and light tart, oddly candyfloss sweet linger.Bottle, Garvies, The Vineyard Belfast  ',
#   ''],
#  ['Boundary a Berliner Vice #3',
#   '364610',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '2.7',
#   '1452164400',
#   'Stuu666',
#   '178977',
#   '3',
#   '7',
#   '3',
#   '6',
#   '13',
#   '3.20',
#   'Bottle at craigâ\x80\x99s. Pours hazy yellow, nose is sharp lemon, lime, taste is zesty, sour, little thin.  ',
#   ''],
#  ['Boundary a Berliner Vice #3',
#   '364610',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '2.7',
#   '1452164400',
#   'allmyvinyl',
#   '128401',
#   '3',
#   '7',
#   '3',
#   '7',
#   '14',
#   '3.40',
#   'Bottle at Craigs. Pours hazy pale yellow with no head. Aromas of salty citrus, lemon. Taste is salty, big lemon, thin finish.  ',
#   ''],
#  ['Boundary a Berliner Vice #3',
#   '364610',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '2.7',
#   '1452164400',
#   'cgarvieuk',
#   '36509',
#   '3',
#   '7',
#   '3',
#   '8',
#   '15',
#   '3.60',
#   'bottle at home ... hazy yellow .. thinest white lacing ... soft peppery ... yuzu fruit nose ... soft fruit .. nig zezty lemon yuzu .. light salty fruit .. juiy fruit ',
#   ''],
#  ['Boundary a Berliner Vice #3',
#   '364610',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '2.7',
#   '1448449200',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '5',
#   '4',
#   '7',
#   '12',
#   '3.20',
#   'bottle at home from ales by mailopaque pale green-blonde with sharp, slightly acetic nose, green apple and cooked corn. nippy carbonation, l ight body with medium creamy mouthfeel from wheat, doughy, lightly fruity, some woody vanilla notes, fairly sweet and only very lightly tart with a hint of lactic yoghurt in finish. ',
#   ''],
#  ['Boundary A Berliner Vice #4 (Nearly Nilsson)',
#   '380990',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '3.4',
#   '1449658800',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '7',
#   '4',
#   '8',
#   '15',
#   '3.80',
#   'Bottle at established cheese & beer eveningdingy zesty tart citrus aroma , light bodied, key lime pie, moderate tartness & carbonation, citrus and lactic, fresh & Moreish ',
#   ''],
#  ['Boundary A Berliner Vice #5 Derek',
#   '412904',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '3.0',
#   '1485687600',
#   'Fin',
#   '32589',
#   '5',
#   '6',
#   '4',
#   '7',
#   '13',
#   '3.50',
#   '  Bottle from Beer Gonzo, Earlsdon, Coventry (I picked this up some months ago) consumed at home Sunday 29th January 2017 whilst cooking Spaghetti Bolagnese.   Pours red with a lovely pink head, this has been in one of my beer fridges for a while, and I note that the date was up last month, that said itâ\x80\x99s still in great nick. Lots of raspberries, itâ\x80\x99s a lovely tart, zappy fruity beautâ\x80\x99. Makes you go clack with your mouth, I like it l, dry finish, tart, zappy, refreshing beer.  A6 A5 T7 P4 Ov13 3.5   ',
#   ''],
#  ['Boundary A Berliner Vice #5 Derek',
#   '412904',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '3.0',
#   '1477648800',
#   'Scopey',
#   '107993',
#   '4',
#   '6',
#   '3',
#   '6',
#   '12',
#   '3.10',
#   'Bottle at home. It pours deep red with a quickly dissipating off-white head. The aroma is raspberry cheesecake, creamy, cherrydrops, earth, barnyard and Victoria sponge. The taste is crisp, tart, juicy raspberry, raspberry pip, jammy, lemon rinse, musty, blue cheese, earth and some acidity with some blue cheese on the finish. Light + body and moderate, prickly. Nice tart raspberry, but the blue cheese character ruins it a bit for me. ',
#   ''],
#  ['Boundary A Berliner Vice #5 Derek',
#   '412904',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '3.0',
#   '1472205600',
#   'Theydon_Bois',
#   '208877',
#   '4',
#   '6',
#   '4',
#   '6',
#   '14',
#   '3.40',
#   'Bottle at home, 26/08/16.Claret with a decent crimson cap.Nose is lightly tarte raspberry, straw, berry pips, light smoke, tangy red berry exhaust.Taste comprises medium sharp raspberry tang, straw, light fruit balsam trace, hay bale, light spice, boysenberry ping. Medium bodied, fine carbonation, sublte puckering finale, drying curtain call.Ok â\x80\x99Linner, decent flavour profile for the ABV, refreshing on a hot summers night. ',
#   ''],
#  ['Boundary A Berliner Vice #6 (Vilca Weisse)',
#   '437437',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '4.4',
#   '1479726000',
#   'Ascelja',
#   '328122',
#   '3',
#   '8',
#   '4',
#   '8',
#   '14',
#   '3.70',
#   '#1021Bottle 0.33l from Vineyard, Belfast. Pale body, medium white head. Aroma of burned coffee, coffee beans, berries, stables, flowers. Taste is prominently sour, very slightly bitter finish. Coffee beans, fruits, spices, flowers, berries. Light body, medium carbonation, easy drinkability. Rich flavored and tasty. ',
#   ''],
#  ['Boundary A Berliner Vice #6 (Vilca Weisse)',
#   '437437',
#   'Boundary',
#   '22818',
#   'Berliner Weisse',
#   '4.4',
#   '1479553200',
#   'Rotin',
#   '334211',
#   '3',
#   '7',
#   '4',
#   '8',
#   '14',
#   '3.60',
#   'Bottle 0.33l. Lightly cloudy, gold colored. AROMA- sour weisse aroma, fruity, lightly funky, roasted cascara aroma. FLAVOR- very smooth, quite sour, refreshing fruity sour beer with roasted coffee-like finish. Light to medium bodied, very well balanced. Great beer. ',
#   ''],
#  ['Boundary American Pale Ale',
#   '328951',
#   'Boundary',
#   '22818',
#   'American Pale Ale',
#   '3.5',
#   '1496829600',
#   'drjoeng',
#   '333038',
#   '4',
#   '5',
#   '3',
#   '5',
#   '12',
#   '2.90',
#   '3.5%ABV. Session pale ale.Poured out rich gold. 8SRM.Nose is immediately acrid with hair salon aroma. On further inspection could be interpreted to be dank and funky with wet dog, mold, fresh mushrooms and canned button mushrooms.Mouthfeel is light and strongly suggestive of mineral water. Malt palate has pale malt with white bread and biscuits. With the mineral body, and the carbohydrate palate, the palate is pushed towards the taste memory of a clear broth ramen. A very similar palate on Mikkellerâ\x80\x99s Ramen Beer. Hops are just there and suggest citrus peel with orange peel being most likely.Finish is airy and brief. Palate is left very clean. ',
#   ''],
#  ['Boundary American Pale Ale',
#   '328951',
#   'Boundary',
#   '22818',
#   'American Pale Ale',
#   '3.5',
#   '1496052000',
#   'nuplastikk',
#   '58251',
#   '3',
#   '6',
#   '3',
#   '6',
#   '14',
#   '3.20',
#   'Tap at Brewdog Clerkenwell. Unfiltered orange body. Earthy, malty, antiquated. A real lack of hop depth. Some pleasant enough British malts. Unimpressive, but certainly drinkable. ',
#   ''],
#  ['Boundary American Pale Ale',
#   '328951',
#   'Boundary',
#   '22818',
#   'American Pale Ale',
#   '3.5',
#   '1492164000',
#   'minutemat',
#   '265702',
#   '3',
#   '5',
#   '3',
#   '5',
#   '12',
#   '2.80',
#   'Keg @ Chez Sophie. Pours a lightly misty gold, small white head. Biscuity malt aroma. Taste continues with a biscuity character, not much in the way of hops or anything else search as I might. Quaffer but thatâ\x80\x99s it.  ',
#   ''],
#  ['Boundary American Pale Ale',
#   '328951',
#   'Boundary',
#   '22818',
#   'American Pale Ale',
#   '3.5',
#   '1491300000',
#   'Erasmus_ro',
#   '123316',
#   '3',
#   '5',
#   '3',
#   '5',
#   '10',
#   '2.60',
#   'Bottle. Pours a clear golden orange with a small, off-white head. Aroma is very subdued. Slight fruit and flower. Taste is subdued and light as well. Slight caramel and nuts, fruitiness, floweriness a bit stronger. Not much flavor. Like drinking water-flavored beer. Good mouthfeel though. ',
#   ''],
#  ['Boundary American Pale Ale',
#   '328951',
#   'Boundary',
#   '22818',
#   'American Pale Ale',
#   '3.5',
#   '1490868000',
#   'LazyPyro',
#   '368991',
#   '3',
#   '7',
#   '3',
#   '6',
#   '12',
#   '3.10',
#   '330ml bottle. Clear golden-amber colour with a small white head, poor retention. Aroma: fairly mild, citrus fruit, floral, yeast. Taste: light sweet, citrus fruits, yeasty, floral, biscuit... all very subdued. Light-medium body, mild bitter finish, well carbonated. ',
#   ''],
#  ['Boundary American Pale Ale',
#   '328951',
#   'Boundary',
#   '22818',
#   'American Pale Ale',
#   '3.5',
#   '1490094000',
#   'themightyjag',
#   '171576',
#   '4',
#   '6',
#   '3',
#   '8',
#   '16',
#   '3.70',
#   '330ml bottle from Brewdog shop.Small white head, good lacing. Clear amber body. Not much on the nose, little hints of tangerine, mango. Flavour has more to it, tangy tropical fruit, a little spice, caramel sweetness running through it, kind of a jammy aftertaste. Medium carbonation, sharp on the tongue, good body for the low abv. Impressive considering its strength, surprisingly tasty. ',
#   ''],
#  ['Boundary American Pale Ale',
#   '328951',
#   'Boundary',
#   '22818',
#   'American Pale Ale',
#   '3.5',
#   '1488538800',
#   'leaparsons',
#   '3352',
#   '3',
#   '6',
#   '3',
#   '6',
#   '12',
#   '3.00',
#   'Bottle, The Offie, Leicester. Golden with a bubbly head. Mellow tropical fruit with stewed apple. Grassy with background toffee malts. Plenty of bitter lemon towards the finish. Oily palate. Lacks oomph.  ',
#   ''],
#  ['Boundary American Pale Ale',
#   '328951',
#   'Boundary',
#   '22818',
#   'American Pale Ale',
#   '3.5',
#   '1487934000',
#   'greenmanalishi',
#   '37155',
#   '3',
#   '7',
#   '2',
#   '6',
#   '9',
#   '2.70',
#   'Bottle............................................ ',
#   ''],
#  ['Boundary American Pale Ale',
#   '328951',
#   'Boundary',
#   '22818',
#   'American Pale Ale',
#   '3.5',
#   '1487156400',
#   'jjsint',
#   '138581',
#   '4',
#   '6',
#   '4',
#   '7',
#   '12',
#   '3.30',
#   'Keg tap at Stoneworks, Peterborough. Dark hold and oh so slightly hazy. Bit of carbonation-infused head. Standard APA smell but taken down a couple of notches: mango, grapefruit, pineapple with a touch of biscuit malt. Bittersweet taste with suggestion of sour in the muted hoppy finish. Well-carbonated. A bit too muted for me to love it but itâ\x80\x99s got nice flavours. ',
#   ''],
#  ['Boundary American Pale Ale',
#   '328951',
#   'Boundary',
#   '22818',
# ...
#   '6.3',
#   '1490353200',
#   'cgarvieuk',
#   '36509',
#   '3',
#   '6',
#   '3',
#   '6',
#   '11',
#   '2.90',
#   'bottle at home .. golden amber .. small white head .. dry grassy hay fruit nose ... herbal orange hay fruit ',
#   ''],
#  ['Farmageddon Mosaic IPA',
#   '422207',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '6.3',
#   '1489662000',
#   'AshtonMcCobb',
#   '124423',
#   '4',
#   '8',
#   '4',
#   '8',
#   '16',
#   '4.00',
#   'On keg at Cloisters. Appearance - golden with a nice fluffy head. Nose - apricot and canned mandarins. Taste - tonnes more apricot. Dried fruit and pith on the finish. Palate - light to medium bodied with a creamy texture and a long dry finish. Overall - beautiful ipa. ',
#   ''],
#  ['Farmageddon Mosaic IPA',
#   '422207',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '6.3',
#   '1488711600',
#   'DruncanVeasey',
#   '36974',
#   '3',
#   '7',
#   '4',
#   '7',
#   '15',
#   '3.60',
#   'Bottle (?), April 2016. Dusted orange capped finely with white. Earthy, gelatinous aroma mingling Fruit Salad, strawberry Campino sweets, blackcurrant and pissy flowers. Soft and cask-like with a solid husky backdrop draped with exotic hop notes approximating white grape, blackcurrant, coconut and lime. Marmalade and butter. A bit rustic and rough around the edges but fine with me ',
#   ''],
#  ['Farmageddon Mosaic IPA',
#   '422207',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '6.3',
#   '1487847600',
#   'thebowtieblogger',
#   '450833',
#   '4',
#   '8',
#   '5',
#   '9',
#   '18',
#   '4.40',
#   'A gorgeous IPA. good abv but still a bright and zippy taste. A beer you could sit and drink a few of no problem. ',
#   ''],
#  ['Farmageddon Mosaic IPA',
#   '422207',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '6.3',
#   '1481108400',
#   'jamestulloch',
#   '138957',
#   '5',
#   '8',
#   '3',
#   '7',
#   '15',
#   '3.80',
#   'Bottle (6.1% ABV) from Ninaâ\x80\x99s Mini Market. Hazy golden body with a creamy white head that holds well. Lively carbonation. Faint lacing. Aroma of mango, cucumber and melon. Flavour of tonic water, nettles and dragon fruit. Medium body with a frothy mouthfeel. Light fizz. Sharp and hoppy. ',
#   ''],
#  ['Farmageddon Mosaic IPA',
#   '422207',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '6.3',
#   '1469354400',
#   'RichTheVillan',
#   '212717',
#   '3',
#   '7',
#   '3',
#   '7',
#   '13',
#   '3.30',
#   'Keg at Birmingham Beer Bash; hazy golden yellow pour with a bubbly white head, aroma has biscuity malts, mango and some light spice, taste has mango, some spice, tangerine. ',
#   ''],
#  ['Farmageddon Mosaic IPA',
#   '422207',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '6.3',
#   '1469181600',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '8',
#   '4',
#   '6',
#   '14',
#   '3.60',
#   'bottle at home from the winerackredcurrants and tangerines on the nose, full bodied, quite pithy, juicy fruit, moderate carbonation, digestive biscuit malt ',
#   ''],
#  ['Farmageddon Mosaic IPA',
#   '422207',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '6.3',
#   '1467540000',
#   'mr_h',
#   '105677',
#   '3',
#   '8',
#   '3',
#   '8',
#   '17',
#   '3.90',
#   'Cask, 1/3 pint, hand-pulled, GRAF 2016, The Briggait, Glasgow (23 Jun 2016), grassy, nettle, toffee aroma, pale golden with a thin bubbly off-white head, toffee, grapefruit, creamy, sweet, good carbonation, voted beer of the festival. ',
#   ''],
#  ['Farmageddon Mosaic IPA',
#   '422207',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '6.3',
#   '1464516000',
#   'The_Osprey',
#   '249130',
#   '4',
#   '5',
#   '3',
#   '5',
#   '13',
#   '3.00',
#   '500ml bottle at home in Richmond - picked up in We Brought Beer last week. As â\x80\x99Farmageddon Brewing Co-Op Mosaic IPAâ\x80\x99, 6.3%, no BB stated. Brewed in County Doyne, or Down, depending on your accent. Dark golden yellow or pale orange, hazy, a few bubbles, dense foamy white head, thick lacing. Aroma is spicy, malted milk biscuits, yoghurt, mango lassi, buttery. A bit weird. Body is light, spritzy carbonation, quite foamy. Taste is spicy sodawater, some burnt ashy notes, gooseberry, a little medicinal, lightly floral. A bit thin. The label tells me to "Expect tropical fruit, citrus and resinous pine" - maybe it delivers a little pine but itâ\x80\x99s mostly as Iâ\x80\x99ve described it. OK, but was hoping for more. ',
#   ''],
#  ['Farmageddon S.M.A.S.H Amarillo',
#   '316201',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '6.7',
#   '1438250400',
#   'MrHangover',
#   '125945',
#   '2',
#   '4',
#   '2',
#   '3',
#   '7',
#   '1.80',
#   'Bottle. Pours a murky, cloudy light pinkish beer with a small, off white head on top. Aroma of fruit, strawberries and metallic aromas. Flavor is very strange, not very bitter, but more like canned strawberries with something chemical added. Really weird. I finished the bottle, but never figured out what that was. Did not really liked it though. That flavor is present troughout entire drinking experience and it overwhelms the aftertaste. Strange stuff.  ',
#   ''],
#  ['Farmageddon S.M.A.S.H Amarillo',
#   '316201',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '6.7',
#   '1431252000',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '6',
#   '3',
#   '1',
#   '3',
#   '1.70',
#   'Bottle from vineyardlooks good, smells fine, good mouthfeel but tastes awful. Possibly chlorine content of the brewing liquor. Whole batch should be pulled. Sad as its just damaging reputation. ',
#   ''],
#  ['Farmageddon S.M.A.S.H Amarillo',
#   '316201',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '6.7',
#   '1424602800',
#   'markc_belfast',
#   '359193',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   '0.70',
#   'From a company that has produced outstanding beers in the past particularly the Mosaic S.M.A.S.H, this Smash is simply awful! ',
#   ''],
#  ['Farmageddon S.M.A.S.H Amarillo',
#   '316201',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '6.7',
#   '1424343600',
#   'ciaranc',
#   '151109',
#   '2',
#   '2',
#   '3',
#   '2',
#   '8',
#   '1.70',
#   'Bottle from Redmonds. Dark amber, almost brown. Vegetal notes, phenols, nail polish and dark fruits. Eh,not sure this is intentional. Flavour is bitter and grassy, all over the place. Alcoholic heat in the finish. Not sure whatâ\x80\x99s going on here, other brews from these guys are very good ',
#   ''],
#  ['Farmageddon S.M.A.S.H Tomahawk',
#   '271284',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'American Pale Ale',
#   'nan',
#   '1402999200',
#   'garthicus',
#   '30639',
#   '3',
#   '3',
#   '2',
#   '4',
#   '8',
#   '2.00',
#   'Appearance: Hazy brown, small snow white head. Aroma: Slightly floral, taking me a long time to get what aromas are there, lavender, quite a milk aroma. Odd. Flavour: Milk again, lavender, butter, cheese? A little bitter, jesus this is a clusterfuck, grain, sour milk, could this be infected? Yikes. *update* as this warms thereâ\x80\x99s an actual bleach/chlorine flavour.  ',
#   ''],
#  ['Farmageddon S.M.A.S.H. Mosaic',
#   '288293',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '5.7',
#   '1435140000',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '8',
#   '4',
#   '4',
#   '12',
#   '3.20',
#   'Bottle at home courtesy of quaire swally, cheers Roypours hazy amber with pillowy white head. Great fruity blueberry and orange on nose. Starts well, jiuicy hop blast, moderate bitterness, moderate carbonation. unfortunately the usual taint lurking in the background makes itself known...disappointing. ',
#   ''],
#  ['Farmageddon Vermont Pale Ale',
#   '516180',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'American Pale Ale',
#   '6.4',
#   '1500372000',
#   'allmyvinyl',
#   '128401',
#   '3',
#   '7',
#   '3',
#   '7',
#   '14',
#   '3.40',
#   'Bottle from Appellation Wines, Dalry Road. Pours hazy pale gold with a thin white head. Aromas of tangerine and peach. Taste is juicy, light sweet orange. Sweet finish.  ',
#   ''],
#  ['Farmageddon Vermont Pale Ale',
#   '516180',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'American Pale Ale',
#   '6.4',
#   '1499508000',
#   'jamestulloch',
#   '138957',
#   '3',
#   '7',
#   '3',
#   '6',
#   '13',
#   '3.20',
#   'Bottle from The Beerhive. Hazy golden body with a thick white head. Lively carbonation. Good lacing. Aroma of peach, gooseberry and straw. Flavour of grain, peach skin, apricot and bitter lemon. Thin to medium body with a watery texture. Soft fizz. Less murky and more bitter than other Vermont style beers Iâ\x80\x99ve tried. ',
#   ''],
#  ['Farmageddon Vermont Pale Ale',
#   '516180',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'American Pale Ale',
#   '6.4',
#   '1498903200',
#   'Stuu666',
#   '178977',
#   '3',
#   '7',
#   '4',
#   '8',
#   '15',
#   '3.70',
#   'Bottle at home. Pours hazy golden orange, nose is mango, orange, taste is juicy mango, passionfruit, dry toffee. ',
#   ''],
#  ['Farmageddon Vermont Pale Ale',
#   '516180',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'American Pale Ale',
#   '6.4',
#   '1497261600',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '7',
#   '4',
#   '7',
#   '14',
#   '3.60',
#   'bottle at home from the wineracklightly hazy mid amber with moderate carbonation. Ripe stone fruit on the nose, peaches, mango and a touch of resin. soft bodied but some bitterness remains to prevent it becoming too cloying. Getting near a neipa but not as cloudy as some! ',
#   ''],
#  ['Farmageddon Vermont Pale Ale',
#   '516180',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'American Pale Ale',
#   '6.4',
#   '1495533600',
#   'AshtonMcCobb',
#   '124423',
#   '4',
#   '7',
#   '4',
#   '7',
#   '14',
#   '3.60',
#   'Bottle from Appellation Wines. Appearance - cloudy, golden amber. Generous fluffy head.Nose - candied orange and resin. Wholemeal bread.Taste - more resin and orange. A touch grainy.Palate - close to medium bodied with a creamy but dry texture. Dry bready finish.Overall - tasty though a touch grainy. ',
#   ''],
#  ['Farmageddon Wet Hop IPA',
#   '302030',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '5.7',
#   '1490353200',
#   'cgarvieuk',
#   '36509',
#   '3',
#   '6',
#   '3',
#   '6',
#   '12',
#   '3.00',
#   'bottle at home ... golden ... small white head ... soft dry herbal fruit .. tiny smoke fruit nose ... over fizzy .. dry bitter herbal fruit .. long fruit ... dry orange ...  ',
#   ''],
#  ['Farmageddon Wet Hop IPA',
#   '302030',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '5.7',
#   '1490353200',
#   'Stuu666',
#   '178977',
#   '3',
#   '7',
#   '3',
#   '6',
#   '12',
#   '3.10',
#   'Bottle at Craigs. Pours clear golden, nose is fruity, pine, toffee, taste is sweet, lemony, pine , little soapy. ',
#   ''],
#  ['Farmageddon Wet Hop IPA',
#   '302030',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '5.7',
#   '1488279600',
#   'Bozo_skeleton',
#   '245608',
#   '5',
#   '7',
#   '4',
#   '6',
#   '14',
#   '3.60',
#   'Blonde dorÃ©e, grosse carbo, collet epais persistant Aromes citronnÃ©s, herbeuxTexture mince, portÃ©e par une amertume citonnee pas tres relevee en finale, seche comme il faut. ',
#   ''],
#  ['Farmageddon Wet Hop IPA',
#   '302030',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '5.7',
#   '1480849200',
#   'jamestulloch',
#   '138957',
#   '4',
#   '7',
#   '4',
#   '5',
#   '12',
#   '3.20',
#   'Bottle (6.3% ABV) from Ninaâ\x80\x99s Mini Market. Hazy bronze body with a medium white head. Lively carbonation. Faint lacing. Aroma of grass, pear, honey and grapefruit. Flavour of stainless steel, tonic water and lime pith. Thin to medium body with an oily texture. Itâ\x80\x99s very astringent - I think a sweeter malt base would have improved this. ',
#   ''],
#  ['Farmageddon Wet Hop IPA',
#   '302030',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '5.7',
#   '1480330800',
#   'wheresthepath',
#   '74729',
#   '3',
#   '7',
#   '4',
#   '7',
#   '14',
#   '3.50',
#   'Bottle from the brewerâ\x80\x99s own stand at the Good Food Show at Birmingham NEC. Light amber with a thin white head and a resinous mouthfeel. Grassy, citrussy flavours, the citrus possibly tending more towards orange than lemon. Restrained but pleasant; I quite enjoyed this.  ',
#   ''],
#  ['Farmageddon Wet Hop IPA',
#   '302030',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '5.7',
#   '1479985200',
#   'Taboada',
#   '101044',
#   '2',
#   '7',
#   '3',
#   '6',
#   '13',
#   '3.10',
#   '500 mml bottle as part of the European Local Swap 4/2016, many thanks Beersiveknown. Tasted on the 23/11/2016. 2016 version is 6.3% ABV. Hazy golden colour with a medium thin white head. Aroma of hops, hay and bread. Taste is tangerine, hops and cereals. Some watery aftertaste. Next one please! ',
#   ''],
#  ['Farmageddon Wet Hop IPA',
#   '302030',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '5.7',
#   '1479380400',
#   'Scottishchris',
#   '286382',
#   '3',
#   '6',
#   '2',
#   '5',
#   '13',
#   '2.90',
#   "Bottle from beerhive. Some harsh reviews from 2015 on here. This bottle (BBE 2017 ? Hard to read) is I presume a different beast given the fresh hops of the season. Dirty Amber with slight pink hue. Small white head. Suspended yeast. Sweet caramel malt and oat nose. Medium light body, very soft fizz. Mouth coating but not too oily. More oats and cereal with underlying tangerine and melon. Medium bitter quite wet finish. I'm not sure about the oat base but have to applaud the effort and intent with the fresh and local hops including the 'particularly vigorous wild Irish hop'. Look forward to trying the others in the range.  ",
#   ''],
#  ['Farmageddon Wet Hop IPA',
#   '302030',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '5.7',
#   '1427108400',
#   'batiburrillo',
#   '362864',
#   '5',
#   '5',
#   '1',
#   '1',
#   '5',
#   '1.70',
#   'Unmistakable, inescapable chemical aftertaste. Persists through tasting. Hated it. ',
#   ''],
#  ['Farmageddon Wet Hop IPA',
#   '302030',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '5.7',
#   '1420196400',
#   'pfcit',
#   '292360',
#   '1',
#   '2',
#   '1',
#   '1',
#   '1',
#   '0.60',
#   'this brew simply didnâ\x80\x99t work. initial hoppiness killed by a badly balanced malt taste. ',
#   ''],
#  ['Farmageddon Wet Hop IPA',
#   '302030',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '5.7',
#   '1417431600',
#   'ciaranc',
#   '151109',
#   '2',
#   '7',
#   '3',
#   '7',
#   '16',
#   '3.50',
#   'Bottle from The Vineyard. Dirty amber, not much head. Nice fresh hop nose. Caramel malt bar with some moderate hop bitterness, some grassiness in the finish. Big body, soft carbonation. Another decent beer from these. ',
#   ''],
#  ['Farmageddon Wet Hop IPA',
#   '302030',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'India Pale Ale (IPA)',
#   '5.7',
#   '1417345200',
#   'Beersiveknown',
#   '128086',
#   '4',
#   '7',
#   '4',
#   '6',
#   '13',
#   '3.40',
#   'Bottle at home from the vineyardPours hazy dark amber brown with fluffy offwhite head with rich, herbal & slightly cheesy aroma. Full bodied, pretty sweet with moderate carbonation, tongue coating hop oils but only gentle bitterness. Lots of vegetation, pepperiness and a touch of pith. Slight hint of tcp at back of palate which hopefully not sign of spoilage. Decent English style IPA and very quaffable ',
#   ''],
#  ['Farmageddon White IPA',
#   '329218',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'Wheat Ale',
#   '3.8',
#   '1470736800',
#   'Erzengel',
#   '83106',
#   '4',
#   '8',
#   '4',
#   '8',
#   '14',
#   '3.80',
#   'Many thanks to Beerhunter111 for sharing!  Smooth fresh and light fruity body. Interesting - not too full body but nice floral piney hops. Moderate bitterness in the aftertaste, hints of Wheat there, very soft and smooth, highly drinkable with a nice floral overlay. For that ABV great sessionable with depth.  ',
#   ''],
#  ['Farmageddon White IPA',
#   '329218',
#   'Farmageddon Brewing Co-Op',
#   '19507',
#   'Wheat Ale',
#   '3.8',
#   '1469613600',
#   'Beerhunter111',
#   '227834',
#   '4',
#   '7',
#   '4',
#   '7',
#   '15',
#   '3.70',
#   '50cl bottle from a trade with Beersiveknown. Pours slightly hazy pale yellow colour with a huge good lasting white head. Aroma of floral dry hops, spices, wheat. Taste of dry floral bitter hops, spices, earthy, wheat. ',
#   ''],
#  ...]

# %%
df_reviews = pd.DataFrame(list_of_lists, columns = ['beer_name', 'beer_id', 'brewery_name', 'brewery_id', 'style', 'abv', 'date', 'user_name', 'user_id', 'appearance', 'aroma', 'palate', 'taste', 'overall', 'rating', 'text', 'newline'])

df_reviews.drop('newline', axis=1, inplace=True)
df_reviews['date'] = pd.to_datetime(df_reviews['date'], unit = 's')
df_reviews.head(2)
# Out:
# /var/folders/15/q349b23s2xz29tmnf290wgs80000gn/T/ipykernel_99434/1632418951.py:4: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_reviews['date'] = pd.to_datetime(df_reviews['date'], unit = 's')
#              beer_name beer_id brewery_name brewery_id       style  abv  \
# 0    33 Export (Gabon)  410549      Sobraga       3198  Pale Lager  5.0
# 1  Castel Beer (Gabon)  105273      Sobraga       3198  Pale Lager  5.2
#
#                  date     user_name user_id appearance aroma palate taste  \
# 0 2016-04-26 09:59:28       Manslow  175852          2     4      2     4
# 1 2017-02-17 10:59:12  MAGICuenca91  442761          2     3      2     4
#
#   overall rating                                               text
# 0       8   2.00  Puszka 0,33l dzięki Christoph . Kolor jasnozło...
# 1       8   1.90  Cerveza pale lager gabonesa. MÃ¡s floja que la...

# %%
df_reviews.to_csv('data/RateBeer/reviews.csv.gz', compression='gzip', columns=['beer_name', 'beer_id', 'brewery_name', 'brewery_id', 'style', 'abv', 'date', 'user_name', 'user_id', 'appearance', 'aroma', 'palate', 'taste', 'overall', 'rating', 'text'], index=False)
